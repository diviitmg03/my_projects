# %%
import torch
import numpy as np
import pandas as pd
import glob

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5x', pretrained=True)
# Out:
# Using cache found in C:\Users\diviit/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-2-21 Python-3.11.2 torch-2.2.0+cpu CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x.pt to yolov5x.pt...
# 100%|██████████| 166M/166M [01:29<00:00, 1.94MB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...

# %%
# Define the image path
image_folder = r"E:\diviit\my_work\iot\yolo\sample_image"
image_paths = glob.glob(image_folder + '*.jpg')

# %%
image_path = "E:\diviit\my_work\iot\yolo\sample_image\image_!.jpg"

# %%
model.conf = 0.50

# %%
# Perform inference
results = model([image_path])

# %%
# Print and save the results
results.print()
results.show()  # or .show()
# Out:
# image 1/1: 405x405 4 persons, 12 cars, 3 motorcycles, 1 bus, 4 trucks
# Speed: 256.9ms pre-process, 7832.0ms inference, 48.1ms NMS per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=405x405>

# %%
results.print()
# Out:
# image 1/1: 405x405 4 persons, 12 cars, 3 motorcycles, 1 bus, 4 trucks
# Speed: 256.9ms pre-process, 7832.0ms inference, 48.1ms NMS per image at shape (1, 3, 640, 640)

# %%
df = results.pandas().xyxy[0]
df  # Print detection results
# Out:
#           xmin        ymin        xmax        ymax  confidence  class  \
# 0    18.385958  244.711395  114.803818  330.614716    0.931470      2
# 1   280.768860  108.068764  328.224548  162.197495    0.902128      7
# 2     0.225360  197.458862   55.469120  244.741425    0.895709      2
# 3   341.125244  191.584518  400.263245  239.093231    0.895169      2
# 4   321.873718  152.310776  367.656464  186.597397    0.860195      2
# 5   261.927673  181.473755  326.104065  240.330460    0.818991      2
# 6    96.632980  175.761337  152.600784  225.359253    0.799557      2
# 7     0.046923  280.253662   13.043328  327.788910    0.794949      2
# 8   117.734367  326.130127  162.464447  399.401733    0.754802      3
# 9   130.126999  192.594421  326.753418  343.847229    0.754749      7
# 10  117.191910  105.333992  168.462585  171.223831    0.747256      7
# 11  118.063705  303.845734  163.197296  374.953735    0.739891      0
# 12  241.571884  148.984009  285.462616  184.781265    0.736219      2
# 13  373.386719  307.634705  404.350494  372.442688    0.735857      0
# 14  358.205017  319.330841  405.000000  398.635101    0.732819      3
# 15   59.307682  151.170334  102.990921  188.788681    0.707187      2
# 16  338.269501  265.005676  376.024261  316.338898    0.698939      3
# 17  169.276093  156.894730  212.751862  195.885818    0.641403      2
# 18   34.166847  131.218719   78.540138  169.523956    0.624111      2
# 19  260.859100  249.148651  278.359039  271.198151    0.539682      0
# 20  343.914368  250.550934  370.946075  278.925385    0.517613      0
# 21  357.506592   83.342964  395.789490  120.862907    0.513395      7
# 22  182.639282  127.220139  215.238785  158.183395    0.505974      2
# 23  150.301651   88.282822  179.432816  121.152649    0.505281      5
#
#           name
# 0          car
# 1        truck
# 2          car
# 3          car
# 4          car
# 5          car
# 6          car
# 7          car
# 8   motorcycle
# 9        truck
# 10       truck
# 11      person
# 12         car
# 13      person
# 14  motorcycle
# 15         car
# 16  motorcycle
# 17         car
# 18         car
# 19      person
# 20      person
# 21       truck
# 22         car
# 23         bus

# %%
df['name'].value_counts()
# Out:
# car           12
# truck          4
# person         4
# motorcycle     3
# bus            1
# Name: name, dtype: int64
